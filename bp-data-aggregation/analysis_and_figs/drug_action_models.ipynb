# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

from bp_aggregation import run_mixed_bp_1to60, run_mixed_ldl_1to60

# %%
BP_RAW_TSV = ""
LDL_RAW_TSV  = ""

# %%
bp_coef, bp_models = run_mixed_bp_1to60(BP_RAW_TSV, save_prefix="mixed_bp_1to60")

# %%
ldl_coef, ldl_model = run_mixed_ldl_1to60(LDL_RAW_TSV, save_prefix="mixed_ldl_1to60")
display(ldl_coef.sort_values("term"))

# %%
bp_coef.to_csv("bp_effects.csv")
