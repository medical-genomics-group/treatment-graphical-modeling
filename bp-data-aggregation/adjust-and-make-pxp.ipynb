# %%
# %load_ext autoreload
# %autoreload 2

# %%
from adjust_and_pxp import process_all, export_adj_individual_phenos
import glob, os

# %%
BASE_DIR = ''
COVAR_FILE = ''
OUT_PXP_ROOT = ''
FAM_PATH = ''

# %%
process_all(BASE_DIR, COVAR_FILE, OUT_PXP_ROOT, FAM_PATH)

# %%
OUT_IND_DIR = ''
export_adj_individual_phenos(BASE_DIR, OUT_IND_DIR, FAM_PATH)

# %%
print("done")
