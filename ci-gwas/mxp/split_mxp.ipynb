# %%
from split_mxp import (
    make_no_cvd_versions_mxp,
    split_all_bp_pre_post_mxp,
    make_cvd_and_drugs_mxp
)

# %%
#split_all_bp_pre_post_mxp()

# %%
make_no_cvd_versions_mxp()

# %%
#make_cvd_and_drugs_mxp()

# %%
print("done")
